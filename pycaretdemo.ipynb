# %%
import numpy as np
import pandas as pd
from pycaret.classification import *

# %%
df=pd.read_csv('liver_disease_1.csv')

# %%
df.head()
# Out:
#    Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65              0.7               0.1                   187
# 1   62             10.9               5.5                   699
# 2   62              7.3               4.1                   490
# 3   58              1.0               0.4                   182
# 4   72              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio Dataset
# 0      3.3                        0.90     Yes
# 1      3.2                        0.74     Yes
# ...

# %%
exp_clf = setup(df, target = 'Dataset', silent=True)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_0a387efa_bd54_11ea_a57f_4f7581257bb3row4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_0a387efa_bd54_11ea_a57f_4f7581257bb3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a387efa_bd54_11ea_a57f_4f7581257bb3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0a387efa_bd54_11ea_a57f_4f7581257bb3row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0a387efa_bd54_11ea_a57f_4f7581257bb3row0_col1" class="data row0 col1" >1794</td>
#             </tr>
#             <tr>
#                         <th id="T_0a387efa_bd54_11ea_a57f_4f7581257bb3level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_174ddf2c_bd54_11ea_a57f_4f7581257bb3 th {
#           text-align: left;
#     }    #T_174ddf2c_bd54_11ea_a57f_4f7581257bb3row0_col0 {
#             text-align:  left;
#         }    #T_174ddf2c_bd54_11ea_a57f_4f7581257bb3row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_174ddf2c_bd54_11ea_a57f_4f7581257bb3row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_174ddf2c_bd54_11ea_a57f_4f7581257bb3row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_174ddf2c_bd54_11ea_a57f_4f7581257bb3row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_174ddf2c_bd54_11ea_a57f_4f7581257bb3row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_174ddf2c_bd54_11ea_a57f_4f7581257bb3row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...

# %%
lr = create_model('lr')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.6585  0.6061  0.8667  0.7222  0.7879 -0.0513
# 1       0.6341  0.7529  0.8276  0.7059  0.7619 -0.0065
# 2       0.6829  0.7155  0.8621  0.7353  0.7937  0.1277
# 3       0.6585  0.6552  0.8276  0.7273  0.7742  0.0860
# 4       0.8049  0.7845  0.9655  0.8000  0.8750  0.4478
# 5       0.7317  0.7586  0.9655  0.7368  0.8358  0.1694
# 6       0.7805  0.8994  1.0000  0.7632  0.8657  0.3204
# 7       0.6829  0.7184  0.9310  0.7105  0.8060  0.0184
# 8       0.7000  0.7586  0.8966  0.7429  0.8125  0.0943
# 9       0.7000  0.7210  0.8966  0.7429  0.8125  0.0943
# Mean    0.7034  0.7370  0.9039  0.7387  0.8125  0.1301
# SD      0.0517  0.0740  0.0570  0.0258  0.0351  0.1440

# %%
plot_model(lr)

# %%
evaluate_model(lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
